# %%
from common.dems_input import DemsInput
import os 
from common.input import WusnInput
os.listdir('data/dems_data')
# Out:
# ['dem9.asc',
#  'dem8.asc',
#  '.~lock.Mo ta du lieu.docx#',
#  'dem5.asc',
#  'dem4.asc',
#  'dem6.asc',
#  'dem7.asc',
#  'dem10.asc',
#  'Mo ta du lieu.docx',
#  'dem3.asc',
#  'dem2.asc',
#  'dem1.asc']

# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import cm
import numpy as np
from matplotlib import ticker


dem = DemsInput.from_file('data/dems_data/dem10.asc')
arr = [x[:41] for x in dem.height[:41]]

inp = WusnInput.from_file('data/viz_data/no-dem10_r25_1.in')
X = np.clip([x.x for x in inp.sensors + inp.relays], 2, 198)
Y = np.clip([x.y for x in inp.sensors + inp.relays], 2, 198)

# for x,y in zip(X,Y):
#     print(x,y)
figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
cp = plt.contourf([x*5 for x in list(range(41))], [x*5 for x in list(range(41))], arr, cmap=cm.YlOrBr, figsize=(500,500))
plt.scatter(x=X, y=Y, color='blue', s=4)
plt.gca().set_aspect('equal', adjustable='box')
cbar = plt.colorbar(cp)
cbar.ax.tick_params(labelsize=14)


# (generate plot here)
# tick_locator = ticker.MaxNLocator(nbins=5)
# cbar.locator = tick_locator
# cbar.update_ticks()
cbar.set_ticks([2560, 2800, 3040, 3280])

plt.xticks()
plt.xticks(fontsize=14)
plt.yticks(np.arange(0, 201, 50))
plt.yticks(fontsize=14)
plt.xlabel('Width', fontsize=15)
plt.ylabel('Height', fontsize=15)
plt.savefig('no.eps', format='eps', dpi=1000)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math
from matplotlib.pyplot import figure

figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
# # gaussian
# mu = 0
# variance = 0.5
# sigma = math.sqrt(variance)
# x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# plt.xlabel('x', fontsize=15)
# plt.ylabel('Probability density', fontsize=15)
# plt.plot(x, stats.norm.pdf(x, mu, sigma))

# gamma
a = 1.99
mean, var, skew, kurt = stats.gamma.stats(a, moments='mvsk')
x = np.linspace(stats.gamma.ppf(0.01, a),
                stats.gamma.ppf(0.99, a), 100)

plt.plot(x, stats.gamma.pdf(x, a),
       '-', label='gamma pdf')
plt.yticks(np.arange(0, 0.4, 0.1))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('x', fontsize=15)
plt.ylabel('Probability density', fontsize=15)

# x = np.linspace (0, 100, 200) 
# y1 = stats.gamma.pdf(x, a=2, loc=1.5) #a is alpha, loc is beta???
# plt.plot(x, y1, "-") 

# ## uniform
# # sigma = math.sqrt(variance)
# x = np.linspace(0, 2, 2000)
# # dist = stats.uniform(0, 3)
# plt.plot(x, x < 1)
# plt.xticks(np.arange(0, 2.1, 0.5))
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# plt.xlabel('x', fontsize=15)
# plt.ylabel('f(x)', fontsize=15)

plt.savefig('gamma.eps', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # aggregate exact results for mfea

# %%
import os

# %%
for i in sorted(os.listdir('results/exact/small')):
    if 'ga' in i:
        print(i.replace('.out1', ''), float(open(os.path.join('results/exact/small', i)).read().split(' ')[-1]))
        
for i in sorted(os.listdir('results/exact/small')):
    if 'no' in i:
        print(i.replace('.out1', ''), float(open(os.path.join('results/exact/small', i)).read().split(' ')[-1]))

for i in sorted(os.listdir('results/exact/small')):
    if 'uu' in i and 'r25' in i:
        print(i.replace('.out1', ''), float(open(os.path.join('results/exact/small', i)).read().split(' ')[-1]))
        

for i in sorted(os.listdir('results/exact/small')):
    if 'uu' in i and 'r50' in i:
        print(i.replace('.out1', ''), float(open(os.path.join('results/exact/small', i)).read().split(' ')[-1]))
# Out:
# ga-dem10_r25_1 0.00062514761
# ga-dem1_r25_1 0.00028478294
# ga-dem2_r25_1 0.00063197341
# ga-dem3_r25_1 0.00093475063
# ga-dem4_r25_1 0.00029668969
# ga-dem5_r25_1 0.00063020053
# ga-dem6_r25_1 0.00062849092
# ga-dem7_r25_1 0.00063602074
# ga-dem8_r25_1 0.0015192558
# ga-dem9_r25_1 0.000479505
# no-dem10_r25_1 0.00029697097
# no-dem1_r25_1 0.00038542432
# no-dem2_r25_1 0.00062477164
# no-dem3_r25_1 0.00070373675
# no-dem4_r25_1 0.00044249219
# no-dem5_r25_1 0.00032593587
# no-dem6_r25_1 0.00043463109
# no-dem7_r25_1 0.0012695135
# no-dem8_r25_1 0.0006170515
# no-dem9_r25_1 0.00029777755
# uu-dem10_r25_1 0.00042885041
# uu-dem1_r25_1 0.0008570592
# uu-dem2_r25_1 0.00067471446
# uu-dem3_r25_1 0.00062131299
# uu-dem4_r25_1 0.00078774057
# uu-dem5_r25_1 0.0018239786
# uu-dem6_r25_1 0.00095513357
# uu-dem7_r25_1 0.0011720005
# uu-dem8_r25_1 0.00097208703
# uu-dem9_r25_1 0.0004281788
# uu-dem10_r50_1 0.022045746
# uu-dem1_r50_1 0.00046292218
# uu-dem2_r50_1 0.00045473791
# ...

# %%
ga-dem10_r25_1 0.00062514761
ga-dem2_r25_1 0.00063197341
ga-dem3_r25_1 0.00093475063
ga-dem4_r25_1 0.00041551551
ga-dem5_r25_1 0.00063020053
ga-dem6_r25_1 0.00063006581
ga-dem7_r25_1 0.00063602074
ga-dem8_r25_1 0.0015192558
ga-dem9_r25_1 0.00062656061
0.00062514761
0.00028478294
0.00063197341
0.00093475063
0.00029668969
0.00063020053
0.00062849092
0.00063602074
0.0015192558
0.000479505
#
0.00029697097
0.00038542432
0.00062477164
0.00070373675
0.00044249219
0.00032593587
0.00043463109
0.0012695135
0.0006170515
0.00029777755
0.00042885041
0.0008570592
0.00067471446
0.00062131299
0.00078774057
0.0018239786
0.00095513357
0.0011720005
0.00097208703
0.0004281788
0.022045746
0.00046292218
0.00045473791
0.00049146294
0.00044601998
0.00045933036
0.00052817095
0.0004431777
0.00044567995
